# %%
import matplotlib.pyplot as plt
from paper_code import *

# %%
# No tourism case
gamma = 0
a = 0
u_0 = 0
sol0 = ode_solver_z(35,0.1,ic(),gamma,a,u_0,True) # make sure to run until equilibrium 
u = sol0[:N]
f = f_so(sol0[:N],sol0[N:2*N],gamma)
z = z_t(u,0,0)
fig,ax = plt.subplots(1,3,figsize = (16,4))
ax[0].plot(x,u)
ax[0].set_xlabel('x')
ax[0].set_ylabel('u')
ax[1].plot(x,f)
ax[1].set_xlabel('x')
ax[1].set_ylabel('f')
ax[2].plot(x,z)
ax[2].set_xlabel('x')
ax[2].set_ylabel('z')
plt.show()
# Out:
# Initial conditions randomized
# a_0 = 0.000
# u_0 = 0.000
# beta = 10.0
# gamma = 0.00
# Solution in 1.58 s
# Total fishing revenue = 2.93
# Total tourism revenue = 0.00

# %%
# No Tourism, habitat damage
gamma = 0.5
a = 0
u_0 = 0
init = sol0 #let's use the previous solution
sol1 = ode_solver_z(1000,0.1,init,gamma,a,u_0,True)
u = sol1[:N]
f = f_so(sol1[:N],sol1[N:2*N],gamma)
z = z_t(u,a,u_0)
fig,ax = plt.subplots(1,3,figsize = (16,4))
ax[0].plot(x,u)
ax[0].set_xlabel('x')
ax[0].set_ylabel('u')
ax[1].plot(x,f)
ax[1].set_xlabel('x')
ax[1].set_ylabel('f')
ax[2].plot(x,z)
ax[2].set_xlabel('x')
ax[2].set_ylabel('z')
plt.show()
# Out:
# a_0 = 0.000
# u_0 = 0.000
# beta = 10.0
# gamma = 0.50
# Solution in 43.78 s
# Total fishing revenue = 2.46
# Total tourism revenue = 0.00

# %%
# No Tourism, habitat damage
gamma = 15
a = 0
u_0 = 0
init = sol2 # or ic() sol0,sol1...
sol2 = ode_solver_z(100,0.1,init,gamma,a,u_0,True)
u = sol2[:N]
f = f_so(sol2[:N],sol2[N:2*N],gamma)
z = z_t(u,a,u_0)
fig,ax = plt.subplots(1,3,figsize = (16,4))
ax[0].plot(x,u)
ax[0].set_xlabel('x')
ax[0].set_ylabel('u')
ax[1].plot(x,f)
ax[1].set_xlabel('x')
ax[1].set_ylabel('f')
ax[2].plot(x,z)
ax[2].set_xlabel('x')
ax[2].set_ylabel('z')
plt.show()
# Out:
# a_0 = 0.000
# u_0 = 0.000
# beta = 10.0
# gamma = 15.00
# Solution in 5.04 s
# Total fishing revenue = 0.94
# Total tourism revenue = 0.00

# %%
# Tourism for gamma = 0.5
gamma = 0.5
a = 0.1
u_0 = 0.5
init = sol1
sol1_1 = ode_solver_z(1000,0.1,init,gamma,a,u_0,True)
u = sol1_1[:N]
f = f_so(sol1_1[:N],sol1_1[N:2*N],gamma)
z = z_t(u,a,u_0)
fig,ax = plt.subplots(1,3,figsize = (16,4))
ax[0].plot(x,u)
ax[0].set_xlabel('x')
ax[0].set_ylabel('u')
ax[1].plot(x,f)
ax[1].set_xlabel('x')
ax[1].set_ylabel('f')
ax[2].plot(x,z)
ax[2].set_xlabel('x')
ax[2].set_ylabel('z')
plt.show()
# Out:
# a_0 = 0.100
# u_0 = 0.500
# beta = 10.0
# gamma = 0.50
# Solution in 40.20 s
# Total fishing revenue = 2.31
# Total tourism revenue = 0.88

# %%
# Tourism for gamma = 0.5
gamma = 0.5
a = 0.8
u_0 = 0.5 
init = sol1
sol1_2 = ode_solver_z(1000,0.1,init,gamma,a,u_0,True)
u = sol1_2[:N]
f = f_so(sol1_2[:N],sol1_2[N:2*N],gamma)
z = z_t(u,a,u_0)
fig,ax = plt.subplots(1,3,figsize = (16,4))
ax[0].plot(x,u)
ax[0].set_xlabel('x')
ax[0].set_ylabel('u')
ax[1].plot(x,f)
ax[1].set_xlabel('x')
ax[1].set_ylabel('f')
ax[2].plot(x,z)
ax[2].set_xlabel('x')
ax[2].set_ylabel('z')
plt.show()
# Out:
# a_0 = 0.800
# u_0 = 0.500
# beta = 10.0
# gamma = 0.50
# Solution in 44.13 s
# Total fishing revenue = 1.39
# Total tourism revenue = 9.63

# %%
# Tourism for gamma = 0.5
gamma = 0.5
a = 1
u_0 = 0.8
init = sol1
sol1_3 = ode_solver_z(100,0.1,init,gamma,a,u_0,True)
u = sol1_3[:N]
f = f_so(sol1_3[:N],sol1_3[N:2*N],gamma)
z = z_t(u,a,u_0)
fig,ax = plt.subplots(1,3,figsize = (16,4))
ax[0].plot(x,u)
ax[0].set_xlabel('x')
ax[0].set_ylabel('u')
ax[1].plot(x,f)
ax[1].set_xlabel('x')
ax[1].set_ylabel('f')
ax[2].plot(x,z)
ax[2].set_xlabel('x')
ax[2].set_ylabel('z')
plt.show()
# Out:
# a_0 = 1.000
# u_0 = 0.800
# beta = 10.0
# gamma = 0.50
# Solution in 4.02 s
# Total fishing revenue = 0.40
# Total tourism revenue = 9.31
